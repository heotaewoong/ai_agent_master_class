# %%
# 해당 셀을 실행해서 python-dotenv 패키지를 설치합니다.
# %pip install python-dotenv

import os
from dotenv import load_dotenv

# .env 파일에 있는 변수들을 파이썬 메모리로 불러옵니다.
load_dotenv()

# 이제 완벽하게 내 API 키가 출력될 것입니다!
print(os.getenv("OPENAI_API_KEY"))
# Out:
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# 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

# %%
# %pip install openai python-dotenv
# Out:
# Collecting openai
#   Downloading openai-2.30.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from openai) (4.12.1)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Using cached jiter-0.13.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from openai) (2.12.5)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Downloading openai-2.30.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.3 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.13.0-cp314-cp314-macosx_11_0_arm64.whl (318 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, jiter, distro, openai
#   WARNING: The script distro is installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [openai]  WARNING: The script openai is installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [openai]
# Successfully installed distro-1.9.0 jiter-0.13.0 openai-2.30.0 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai

client = openai.OpenAI()

PROMPT = """
I have the following functions in my system.

'get_weather'
'get_currency'
'get_news'

All of them receive the name of a country as an argument (i.e get_news('Spain'))

Please answer with the name of the function that you would like me to run.

Please say nothing else, just the name of the function with the arguments 

Answer the following question:

What is the weather in Greece?
"""

response = client.chat.completions.create(
    model = "gpt-4o-mini",
    messages = [
        {
            "role": "user",
            "content": PROMPT
            
        }
    ],
) 

response
# Out:
# ChatCompletion(id='chatcmpl-DRumx4lSfPuXV2bvKg5JMWYQ00oLC', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="get_weather('Greece')", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1775545523, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_162d3c480f', usage=CompletionUsage(completion_tokens=6, prompt_tokens=92, total_tokens=98, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
message = response.choices[0].message.content 

message
# Out:
# "get_weather('Greece')"
